# %%
# import python libraries
import hvplot.pandas
import warnings
import pandas as pd

warnings.filterwarnings('ignore')

# %%
# Defining URL link to data
t_data_la = ('https://www.ncei.noaa.gov/access/monitoring/climate-at-a-glance/city/time-series/USW00012916/tmax/12/7/1895-2023.csv')
t_data_la
# Out:
# 'https://www.ncei.noaa.gov/access/monitoring/climate-at-a-glance/city/time-series/USW00012916/tmax/12/7/1895-2023.csv'

# %%
# Import Los Angeles temperature values from NCEI
t_data_la_df = pd.read_csv(t_data_la, header=3, names=['year', 'Temp_f'])
t_data_la_df
# Out:
#       year  Temp_f
# 0   194907    77.7
# 1   195007    78.4
# 2   195107    77.5
# 3   195207    78.8
# 4   195307    77.6
# ..     ...     ...
# 70  201907    79.7
# 71  202007    81.5
# 72  202107    78.9
# 73  202207    80.8
# 74  202307    81.0
#
# [75 rows x 2 columns]

# %%
t_data_la_df.year = pd.to_datetime(t_data_la_df.year, format='%Y%m').dt.year
t_data_la_df
# Out:
#     year  Temp_f
# 0   1949    77.7
# 1   1950    78.4
# 2   1951    77.5
# 3   1952    78.8
# 4   1953    77.6
# ..   ...     ...
# 70  2019    79.7
# 71  2020    81.5
# 72  2021    78.9
# 73  2022    80.8
# 74  2023    81.0
#
# [75 rows x 2 columns]

# %%
# Compute Celcius temperatures
t_data_la_df['Temp_c'] = (t_data_la_df['Temp_f'] - 32) * 5 / 9
t_data_la_df
# Out:
#     year  Temp_f     Temp_c
# 0   1949    77.7  25.388889
# 1   1950    78.4  25.777778
# 2   1951    77.5  25.277778
# 3   1952    78.8  26.000000
# 4   1953    77.6  25.333333
# ..   ...     ...        ...
# 70  2019    79.7  26.500000
# 71  2020    81.5  27.500000
# 72  2021    78.9  26.055556
# 73  2022    80.8  27.111111
# 74  2023    81.0  27.222222
#
# [75 rows x 3 columns]

# %% [markdown]
# ### plot desctiption
# Temperatures rising in New Orleans, Louisiana over the past 50 years

# %%
# Plot thte Los Angeles Temperature data over time
t_data_la_df.hvplot(x='year', y='Temp_f',
    title='Mean Annual Temperature - New Orleans, Louisiana, USA',
    xlabel='Year',
    ylabel='Temperature (°F)')
# Out:
# :Curve   [year]   (Temp_f)

# %%
# %%capture
# %%bash
jupyter nbconvert nola-analysis-temp.ipynb --to html --no-input
